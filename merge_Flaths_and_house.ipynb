# %%
import pandas as pd
import numpy as np
import re

# %%
flats = pd.read_csv('/content/sample_data/flats_cleaned.csv')
houses = pd.read_csv('/content/sample_data/house_cleaned.csv')

# %%
print(flats.shape)
houses.shape
# Out:
# (2997, 20)
# (964, 20)

# %%
df = pd.concat([flats,houses],ignore_index=True)

# %%
df = df.sample(df.shape[0],ignore_index=True)

# %%
df.head()
# Out:
#                                     property_name property_type  \
# 0                 3 BHK Flat in Sector 85 Gurgaon          flat
# 1  4 Bedroom House for sale in Sector 17B Gurgaon         house
# 2                3 BHK Flat in Sector 70A Gurgaon          flat
# 3        12 Bedroom House for sale in DLF Phase 2         house
# 4                 3 BHK Flat in Sector 76 Gurgaon          flat
#
#                      society  price  price_per_sqft    area  \
# 0                 godrej air   1.83         10005.0  1829.0
# 1                independent   8.50         18814.0  4518.0
# 2    aipl the peaceful homes   2.30         10697.0  2150.0
# 3  floor wise designer kothi  13.00         48148.0  2700.0
# 4        whiteland the aspen   3.35         17615.0  1902.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0                   Carpet area: 1829 (169.92 sq.m.)        3         3
# 1  Plot area 502(419.74 sq.m.)Built Up area: 500 ...        4         4
# 2             Super Built up area 2150(199.74 sq.m.)        3         3
# 3                        Plot area 300(250.84 sq.m.)       12        16
# 4                   Carpet area: 1900 (176.52 sq.m.)        3         4
#
#   balcony                                 additionalRoom  \
# 0      3+                                  not available
# 1       2             pooja room,study room,servant room
# 2       3                                     store room
# 3      3+  pooja room,study room,servant room,store room
# 4      3+                                   servant room
#
#                                              address  floorNum      facing  \
# 0                Sector 85 Gurgaon, Gurgaon, Haryana      18.0         NaN
# 1        00005, Sector 17B Gurgaon, Gurgaon, Haryana       2.0        West
# 2               Sector 70A Gurgaon, Gurgaon, Haryana       3.0  North-East
# 3  Floor Wise Designer Kothi, DLF Phase 2, Gurgao...       4.0  North-East
# 4                Sector 76 Gurgaon, Gurgaon, Haryana       5.0  North-East
#
#      agePossession                                    nearbyLocations  \
# 0         Mar 2024  ['Sapphire 83 Mall', 'Sector 86 Road', 'Dwarka...
# 1     10+ Year Old  ['Iffco chowk metro station', 'Mg road metro s...
# 2  1 to 5 Year Old  ['Airia Mall', 'Golf Corse Ext. Rd.', 'Nationa...
# 3  0 to 1 Year Old  ['Vodafone belvedere towers metro station', 'D...
# 4         Sep 2027  ['Sector 54 Chowk Metro Station', 'Delhi Jaipu...
#
#                                          description  \
# 0  Godrej air is one of gurgaon's most sought aft...
# 1  House for sale plot 502 sqyard 4 bedroom, dupl...
# 2  This 3 bhk flat is located in aipl the peacefu...
# 3  Floor wise designer kothi near market & metro ...
# 4  Whiteland the aspen is one of gurgaon's most s...
#
#                                       furnishDetails  \
# 0  ['1 Exhaust Fan', '1 Modular Kitchen', 'No AC'...
# 1  ['4 Wardrobe', '10 Fan', '1 Exhaust Fan', '5 G...
# 2  ['3 Wardrobe', '5 Fan', '1 Exhaust Fan', '3 Ge...
# 3  ['1 Water Purifier', '36 Fan', '1 Exhaust Fan'...
# 4  ['1 Water Purifier', '1 Fridge', '1 Geyser', '...
#
#                                             features  \
# 0  ['Security / Fire Alarm', 'Lift(s)', 'Centrall...
# 1  ['Water Storage', 'Visitor Parking', 'Waste Di...
# 2  ['Security / Fire Alarm', 'Power Back-up', 'Fe...
# 3  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 4  ['Centrally Air Conditioned', 'Security / Fire...
#
#                                               rating
# 0  ['Environment5 out of 5', 'Safety4.5 out of 5'...
# 1  ['Environment5 out of 5', 'Safety5 out of 5', ...
# 2  ['Green Area5 out of 5', 'Construction4.5 out ...
# 3  ['Environment5 out of 5', 'Lifestyle5 out of 5...
# 4                                                NaN

# %%
df.to_csv('gurgaon_properties.csv',index=False)
